# %% [markdown]
# <a href="https://colab.research.google.com/github/dbace23/hacktiv8/blob/main/h8dsft_Inferential.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("covid.csv")
df.head()
# Out:
#        Date  ... Growth Factor of New Deaths
# 0  3/1/2020  ...                         NaN
# 1  3/2/2020  ...                         1.0
# 2  3/2/2020  ...                         NaN
# 3  3/2/2020  ...                         NaN
# 4  3/3/2020  ...                         1.0
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20816 entries, 0 to 20815
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         20816 non-null  object
#  1   Location ISO Code            20816 non-null  object
#  2   Location                     20816 non-null  object
#  3   New Cases                    20816 non-null  int64
#  4   New Deaths                   20816 non-null  int64
#  5   New Recovered                20816 non-null  int64
#  6   New Active Cases             20816 non-null  int64
#  7   Total Cases                  20816 non-null  int64
#  8   Total Deaths                 20816 non-null  int64
#  9   Total Recovered              20816 non-null  int64
#  10  Total Active Cases           20816 non-null  int64
#  11  Location Level               20816 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
pd.to_datetime(df['Date'])
df['Day'] = pd.DatetimeIndex(df['Date']).day
df['Year'] = pd.DatetimeIndex(df['Date']).year
case = df[['Date','New Cases','Day','Year']] 
print('Average new case for 2020: {}'.format(np.round(case.loc[case['Year']==2020,'New Cases'].mean())))
print('Average new case up till now: {}'.format(np.round(case['New Cases'].mean())))
# Out:
# Average new case for 2020: 149.0
# Average new case up till now: 408.0

# %%
#pembuktian bahwa H0: μ=149 ,  H1: μ > 149
t_stat,p_val = stats.ttest_1samp(case['New Cases'], 149)
print('P-value:',p_val/2) #The p-value divided by 2 since the output is two-sided p-value
print('t-statistics:',t_stat)

#karena p value lebih besar dari 0.05 maka h null ditolak
# Out:
# P-value: 2.0656741507477563e-69
# t-statistics: 17.636254793666822
